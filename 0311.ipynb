# %% [markdown]
# # Create Df from numoy array 8*5

# %%
import pandas as pd 
import numpy as np
df =pd.DataFrame(np.random.randint(1,100,(8,5)),columns=['A','B','C','D','E'])


print(df.shape)
print(df.size)
print(df.ndim)


df['Sum']=df['A']+df['B']+df['C']+df['D']+df['E']

df.iloc[5,2]=70

print(df.loc[2:7,'B':'D'])

df.loc[10]=[70,20,50,30,20,200]
# Out:
# (8, 5)
# 40
# 2
#     B   C   D
# 2  43  85  89
# 3  56   3  98
# 4  47  41  90
# 5  67  70  92
# 6  32  56  74
# 7  50   2  75

# %%
df1=pd.DataFrame([['c1','a',2,'v'],['c2','b',3,'h'],['c3','c',4,'a'],['c4','d',5,'v'],['c5','h',6,'a']],columns=['CourseId','CourseName','Credits','Faculty'])
print(df1)
df1=df.set_index('CourseId')
print(df1)
df1.iloc[1,1]=7
df1.loc['c6']=['i',7,'d',1]
print(df1)
# Out:
#   CourseId CourseName  Credits Faculty
# 0       c1          a        2       v
# 1       c2          b        3       h
# 2       c3          c        4       a
# 3       c4          d        5       v
# 4       c5          h        6       a
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-fb7b2c1af450> in <module>
#       1 df1=pd.DataFrame([['c1','a',2,'v'],['c2','b',3,'h'],['c3','c',4,'a'],['c4','d',5,'v'],['c5','h',6,'a']],columns=['CourseId','CourseName','Credits','Faculty'])
#       2 print(df1)
# ----> 3 df1=df.set_index('CourseId')
#       4 print(df1)
#       5 df1.iloc[1,1]=7
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
# ...

# %%
df2=pd.read_csv('train.csv')
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # to see head by default 5

# %%
df2.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # to see tail by default 5

# %%
df2.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df2.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # to see random

# %%
df2.sample()
# Out:
#      PassengerId  Survived  Pclass                    Name   Sex  Age  SibSp  \
# 384          385         0       3  Plotcharsky, Mr. Vasil  male  NaN      0
#
#      Parch  Ticket    Fare Cabin Embarked
# 384      0  349227  7.8958   NaN        S

# %%
df2.sample(7)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 103          104         0       3        Johansson, Mr. Gustaf Joel    male
# 869          870         1       3   Johnson, Master. Harold Theodor    male
# 197          198         0       3  Olsen, Mr. Karl Siegwart Andreas    male
# 303          304         1       2               Keane, Miss. Nora A  female
# 337          338         1       1   Burns, Miss. Elizabeth Margaret  female
# 370          371         1       1       Harder, Mr. George Achilles    male
# 754          755         1       2  Herman, Mrs. Samuel (Jane Laver)  female
#
#       Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 103  33.0      0      0    7540    8.6542   NaN        S
# 869   4.0      1      1  347742   11.1333   NaN        S
# 197  42.0      0      1    4579    8.4042   NaN        S
# 303   NaN      0      0  226593   12.3500  E101        Q
# 337  41.0      0      0   16966  134.5000   E40        C
# ...

# %% [markdown]
# # info of csv file

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # to give count mean min percentile 25 50 75 and max

# %%
box plot ma percentile ae 25,50,75 che aiya =>

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # describre(include)

# %%
df2.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass               Name   Sex  \
# count    891.000000  891.000000  891.000000                891   891
# unique          NaN         NaN         NaN                891     2
# top             NaN         NaN         NaN  Fortune, Mr. Mark  male
# freq            NaN         NaN         NaN                  1   577
# mean     446.000000    0.383838    2.308642                NaN   NaN
# std      257.353842    0.486592    0.836071                NaN   NaN
# min        1.000000    0.000000    1.000000                NaN   NaN
# 25%      223.500000    0.000000    2.000000                NaN   NaN
# 50%      446.000000    0.000000    3.000000                NaN   NaN
# 75%      668.500000    1.000000    3.000000                NaN   NaN
# max      891.000000    1.000000    3.000000                NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare    Cabin  \
# ...

# %% [markdown]
# # stratical analysis complete

# %%
df2.describe(include='object')
# Out:
#                      Name   Sex Ticket    Cabin Embarked
# count                 891   891    891      204      889
# unique                891     2    681      147        3
# top     Fortune, Mr. Mark  male   1601  B96 B98        S
# freq                    1   577      7        4      644

# %% [markdown]
# # describt(exclude)

# %%
df2.describe(exclude="int64")
# Out:
#                      Name   Sex         Age Ticket        Fare    Cabin  \
# count                 891   891  714.000000    891  891.000000      204
# unique                891     2         NaN    681         NaN      147
# top     Fortune, Mr. Mark  male         NaN   1601         NaN  B96 B98
# freq                    1   577         NaN      7         NaN        4
# mean                  NaN   NaN   29.699118    NaN   32.204208      NaN
# std                   NaN   NaN   14.526497    NaN   49.693429      NaN
# min                   NaN   NaN    0.420000    NaN    0.000000      NaN
# 25%                   NaN   NaN   20.125000    NaN    7.910400      NaN
# 50%                   NaN   NaN   28.000000    NaN   14.454200      NaN
# 75%                   NaN   NaN   38.000000    NaN   31.000000      NaN
# max                   NaN   NaN   80.000000    NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# ...

# %% [markdown]
# # to change percentile

# %%
df2.describe(percentiles=(0.2,0.3,0.8))
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 20%     179.000000    0.000000    1.000000   19.000000    0.000000
# 30%     268.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 80%     713.000000    1.000000    3.000000   41.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 20%      0.000000    7.854200
# 30%      0.000000    8.050000
# 50%      0.000000   14.454200
# 80%      1.000000   39.687500
# ...

# %% [markdown]
# # to see unique value in whole df

# %% [markdown]
# # df.nunique() column wise unique values

# %%
df2.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# # categarial values?

# %%
df2.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # numerical not a catagery

# %% [markdown]
# # survive pclass sex and embarked

# %%
df2.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df2.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df2.Embarked.unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# df2.Ticket.unique() all are unique so all values will be shown

# %%
df2.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df2.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %% [markdown]
# # Servied male and female

# %% [markdown]
# # total 891 survied 342

# %%
df2[df2["Survived"]==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2[df2["Survived"]==1]["Sex"].value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
df2["Age"]>18
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
df2[df2["Age"]>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # pclass 1 2 3 survial count

# %%
df2[df2["Survived"]==1]["Pclass"].value_counts()
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %% [markdown]
# # Blank Data

# %%
df2.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df2.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df2.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data=pd.DataFrame([[1,2,3,np.nan],[4,np.nan,5,np.nan],[7,8,9,10],[1,np.nan,3,4]])
data
# Out:
#    0    1  2     3
# 0  1  2.0  3   NaN
# 1  4  NaN  5   NaN
# 2  7  8.0  9  10.0
# 3  1  NaN  3   4.0

# %% [markdown]
# # to drop nan

# %%
data.dropna()
# Out:
#    0    1  2     3
# 2  7  8.0  9  10.0

# %%
data.dropna(how='any')
# Out:
#    0    1  2     3
# 2  7  8.0  9  10.0

# %% [markdown]
# # by default data.dropna(how='any')

# %%
data=pd.DataFrame([[1,2,3,np.nan],[4,np.nan,5,np.nan],[7,8,9,10],[1,np.nan,3,4],[np.nan,np.nan,np.nan,np.nan]])
data
# Out:
#      0    1    2     3
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0
# 4  NaN  NaN  NaN   NaN

# %%
data.dropna(how='any')
# Out:
#      0    1    2     3
# 2  7.0  8.0  9.0  10.0

# %%
data.dropna(how='all')
# Out:
#      0    1    2     3
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0

# %%
data
# Out:
#      0    1    2     3
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0
# 4  NaN  NaN  NaN   NaN

# %% [markdown]
# # numpy x=0 => column  x=1 => row

# %% [markdown]
# # pandas ma x=0 => row x=1 => column

# %%
data.dropna(axis=0,how='any')
# Out:
#      0    1    2     3
# 2  7.0  8.0  9.0  10.0

# %%
data.dropna(axis=1,how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
data=pd.DataFrame([[1,2,3,np.nan],[4,np.nan,5,np.nan],[7,8,9,10],[1,np.nan,3,4]])
data
# Out:
#    0    1  2     3
# 0  1  2.0  3   NaN
# 1  4  NaN  5   NaN
# 2  7  8.0  9  10.0
# 3  1  NaN  3   4.0

# %%
data.dropna(axis=1,how='any')
# Out:
#    0  2
# 0  1  3
# 1  4  5
# 2  7  9
# 3  1  3

# %%
data=pd.DataFrame([[1,2,3,np.nan],[4,np.nan,5,np.nan],[7,8,9,10],[1,np.nan,3,4],[np.nan,np.nan,np.nan,np.nan]],columns=["A","B","C","D"])
data
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0
# 4  NaN  NaN  NaN   NaN

# %%
data.dropna(axis=0,how='any',subset=["A"])
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0

# %%
data.dropna(axis=0,how='any',subset=["B"])
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 2  7.0  8.0  9.0  10.0

# %%
data.dropna(axis=0,how='any',subset=["D"])
# Out:
#      A    B    C     D
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0

# %%
data.dropna(axis=0,how='any',subset=["B","D"])
# Out:
#      A    B    C     D
# 2  7.0  8.0  9.0  10.0

# %%
data.dropna(axis=0,how='all',subset=["B","D"])
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0

# %% [markdown]
# # thresh MCQ fav   data.dropna(thresh=2)  2 or 2 thi vadhare fill to j rai or drop

# %%
data
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0
# 4  NaN  NaN  NaN   NaN

# %%
data.dropna(thresh=2)
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0

# %%
data.dropna(thresh=3)
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0

# %%
data.dropna(thresh=4)
# Out:
#      A    B    C     D
# 2  7.0  8.0  9.0  10.0

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # cabin ma data na hoi ae drop

# %%
df2.dropna(subset=["Cabin"])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0
# 4  NaN  NaN  NaN   NaN

# %% [markdown]
# # Fill nan data using mean median and  mode

# %% [markdown]
# # if continuos value mean

# %% [markdown]
# # middle ma value avti hoi ae na mate median

# %% [markdown]
# # frequency hoi tyare mode for category datas

# %%
data
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0
# 4  NaN  NaN  NaN   NaN

# %%
data.fillna(data.mean())
# Out:
#       A    B    C     D
# 0  1.00  2.0  3.0   7.0
# 1  4.00  5.0  5.0   7.0
# 2  7.00  8.0  9.0  10.0
# 3  1.00  5.0  3.0   4.0
# 4  3.25  5.0  5.0   7.0

# %% [markdown]
# # A mean B median C mode

# %%
data
# Out:
#      A    B    C     D
# 0  1.0  2.0  3.0   NaN
# 1  4.0  NaN  5.0   NaN
# 2  7.0  8.0  9.0  10.0
# 3  1.0  NaN  3.0   4.0
# 4  NaN  NaN  NaN   NaN

# %%
data["A"]=data["A"].fillna(data["A"].mean())

# %%
data
# Out:
#       A    B    C     D
# 0  1.00  2.0  3.0   NaN
# 1  4.00  NaN  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  NaN  3.0   4.0
# 4  3.25  NaN  NaN   NaN

# %%
data["B"]=data["B"].fillna(data["B"].median())
data
# Out:
#       A    B    C     D
# 0  1.00  2.0  3.0   NaN
# 1  4.00  5.0  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  5.0  3.0   4.0
# 4  3.25  5.0  NaN   NaN

# %%
data["C"]=data["C"].fillna(data["C"].mode())
data
# Out:
#       A    B    C     D
# 0  1.00  2.0  3.0   NaN
# 1  4.00  5.0  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  5.0  3.0   4.0
# 4  3.25  5.0  NaN   NaN

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Age fill by mean and Embarked by mode

# %%
df2["Age"]=df2["Age"].fillna(df2.Age.mean())

# %%
df2.Age.mean()
# Out:
# 29.699117647058763

# %%
df2.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Mode ma ans avitna ave che like obj/series but in mean and  mode direct ans ai jai j puct thai jai

# %%
df2.Embarked.mode()
# Out:
# 0    S
# dtype: object

# %%
df2.Embarked.mode()[0]
# Out:
# 'S'

# %%
df2["Embarked"]=df2["Embarked"].fillna(df2.Embarked.mode()[0])

# %% [markdown]
# # agar embarked ma [0] karvanu bhuli gya to data type badalai jase

# %%
df2.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
data
# Out:
#       A    B    C     D
# 0  1.00  2.0  3.0   NaN
# 1  4.00  5.0  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  5.0  3.0   4.0
# 4  3.25  5.0  NaN   NaN

# %% [markdown]
# # drop perticular col or row doesn't care if it has null value or not

# %%
data.drop(0) #row0
# Out:
#       A    B    C     D
# 1  4.00  5.0  5.0   NaN
# 2  7.00  8.0  9.0  10.0
# 3  1.00  5.0  3.0   4.0
# 4  3.25  5.0  NaN   NaN

# %%
data.drop("B",axis=1)#colB
# Out:
#       A    C     D
# 0  1.00  3.0   NaN
# 1  4.00  5.0   NaN
# 2  7.00  9.0  10.0
# 3  1.00  3.0   4.0
# 4  3.25  NaN   NaN

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# # drop row jema b female avti hoi

# %%
df2[(df2["Sex"]=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# ..                                                 ...     ...        ...
# ...

# %%
df2[(df2["Sex"]!='female')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#            Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
i=df2[df2["Sex"]=='female'].index
df2.drop(i)
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#            Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # for duplicate data

# %%
ds=pd.DataFrame([[1,1,2,3],[2,1,1,3],[1,1,2,3],[2,1,1,3],[1,1,2,2]],index=[7,8,9,10,11],columns=['p','q','r','s'])
ds
# Out:
#     p  q  r  s
# 7   1  1  2  3
# 8   2  1  1  3
# 9   1  1  2  3
# 10  2  1  1  3
# 11  1  1  2  2

# %% [markdown]
# # to see duplicate value

# %%
ds.duplicated()
# Out:
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# dtype: bool

# %%
ds.duplicated().sum()
# Out:
# 2

# %%
ds.duplicated(subset=["p"])
# Out:
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# dtype: bool

# %% [markdown]
# # by default keep first

# %%
ds.drop_duplicates(keep='last')
# Out:
#     p  q  r  s
# 9   1  1  2  3
# 10  2  1  1  3
# 11  1  1  2  2

# %%
ds.drop_duplicates()
# Out:
#     p  q  r  s
# 7   1  1  2  3
# 8   2  1  1  3
# 11  1  1  2  2

# %%
ds.drop_duplicates(keep='first')
# Out:
#     p  q  r  s
# 7   1  1  2  3
# 8   2  1  1  3
# 11  1  1  2  2

# %%
ds.drop_duplicates(subset=["p"])
# Out:
#    p  q  r  s
# 7  1  1  2  3
# 8  2  1  1  3

# %%
ds.drop_duplicates(subset=["p",'q'])
# Out:
#    p  q  r  s
# 7  1  1  2  3
# 8  2  1  1  3
